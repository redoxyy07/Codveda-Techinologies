# %% [markdown]
# # Task 1 : Regression Analysis

# %% [markdown]
# ## Objectives :
#     - Split the dataset into training and testing sets.
#     - Fit a Linear Regression model using scikit-learn.
#     - Intercept the coefficients and evaluate the model using metrics such as R-squared error & mean squared error.

# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### 2. Reading the CSV file

# %%
a = pd.read_csv(r"C:\Users\Rudra Pratap Swain\OneDrive\Desktop\CodVeda\LEVEL - 1\Data Preprocessing\Cleaned Churn 80 Dataset.csv")
print(a)
# Out:
#          State  Account length  Area code  International plan  \
# 0    -0.672700        0.692163  -0.527811           -0.335690
# 1     0.600844        0.161278  -0.527811           -0.335690
# 2     0.332730        0.919686  -0.527811           -0.335690
# 3     0.600844       -0.420168  -0.692467            2.978938
# 4     0.667873       -0.647691  -0.527811            2.978938
# ...        ...             ...        ...                 ...
# 2661  0.935988       -0.546569  -0.527811           -0.335690
# 2662 -1.544073        2.310100  -0.527811           -0.335690
# 2663  1.539245       -0.824652  -0.527811           -0.335690
# 2664  0.868959       -1.835863   1.706797           -0.335690
# 2665  1.070045       -0.672971  -0.527811           -0.335690
#
#       Voice mail plan  Number vmail messages  Total day minutes  \
# 0            1.623917               1.247508           1.579670
# 1            1.623917               1.320985          -0.329918
# ...

# %% [markdown]
# ### 3. Selecting the dependent and independent features

# %%
x = a[['Total day minutes']]
y = a[['Total day charge']]

# %% [markdown]
# ### 4. Train - Test Splitting

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### 5. Fitting Linear Regression Model

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 6. Interpret Coefficient

# %%
print("Intercept : ",lr.intercept_)
print("Coefficient : ",lr.coef_)
# Out:
# Intercept :  [2.26922831e-06]
# Coefficient :  [[1.00000235]]

# %% [markdown]
# ### 7. Model Evaluation

# %%
y_pred = lr.predict(x_test)

# %%
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error : ",mse)
print("R-squared Error : ",r2)
# Out:
# Mean Squared Error :  1.0149028224559173e-07
# R-squared Error :  0.9999999018196307
