# %% [markdown]
# # Task 2 : Explotary Data Analysis

# %% [markdown]
# ## Objectives :
#     - Calculate Summary Statistics (Mean, Median, Mode, Standard Deviation).
#     - Visualize data distribution using Histogram, Boxplot, Scatter plot.
#     - Find correlation between numerical features.

# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Reading the CSV file

# %%
a = pd.read_csv(r"C:\Users\Rudra Pratap Swain\OneDrive\Desktop\CodVeda\DATASETS\3) Sentiment dataset.csv")
print(a)
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %% [markdown]
# ### 3. Checking Null values

# %%
a.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %% [markdown]
# ### 4. Verifying Datatypes

# %%
a.dtypes
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# Text             object
# Sentiment        object
# Timestamp        object
# User             object
# Platform         object
# Hashtags         object
# Retweets        float64
# Likes           float64
# Country          object
# Year              int64
# Month             int64
# Day               int64
# Hour              int64
# dtype: object

# %%
a['Retweets'] = a['Retweets'].astype('int64')

# %%
a['Likes'] = a['Likes'].astype('int64')

# %%
a.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %% [markdown]
# ### 5. Summary Statistics

# %%
num_col = a.select_dtypes(include=['number'])

# %% [markdown]
# #### a) Mean :
#     Mean is the sum of all values divided by the number of values.

# %%
num_col.mean()
# Out:
# Unnamed: 0.1     366.464481
# Unnamed: 0       369.740437
# Retweets          21.508197
# Likes             42.901639
# Year            2020.471311
# Month              6.122951
# Day               15.497268
# Hour              15.521858
# dtype: float64

# %% [markdown]
# #### b) Median :
#     Median is the middle value when the values are sorted.

# %%
num_col.median()
# Out:
# Unnamed: 0.1     366.5
# Unnamed: 0       370.5
# Retweets          22.0
# Likes             43.0
# Year            2021.0
# Month              6.0
# Day               15.0
# Hour              16.0
# dtype: float64

# %% [markdown]
# #### c) Mode :
#     Mode is the value that occurs most of the times in a dataset or a sequence.

# %%
num_col.mode().iloc[0]
# Out:
# Unnamed: 0.1       0.0
# Unnamed: 0         0.0
# Retweets          22.0
# Likes             45.0
# Year            2023.0
# Month              2.0
# Day               15.0
# Hour              14.0
# Name: 0, dtype: float64

# %% [markdown]
# #### d) Standard Deviation :
#     It measures the amount of variation from the mean.

# %%
num_col.std()
# Out:
# Unnamed: 0.1    211.513936
# Unnamed: 0      212.428936
# Retweets          7.061286
# Likes            14.089848
# Year              2.802285
# Month             3.411763
# Day               8.474553
# Hour              4.113414
# dtype: float64

# %% [markdown]
# ### 6. Visualizating Data Distribution

# %% [markdown]
# #### a) Histogram

# %%
plt.figure(figsize=(10,6))
a['Likes'].hist(bins=20, grid=False, rwidth=0.9, edgecolor='Black')
plt.title("Histogram of Likes")
plt.xlabel("Likes")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Interpretation :
#     This histogram is used to represent the distribution of Likes.
#     Most of the posts are getting around 30-50 likes.
#     Most of the likes are from the left side that indicates that the graph is 'Right Skewed'.
#     The Maximum likes is about 80 and the minimum number of likes is 10.

# %% [markdown]
# #### b) Box Plot

# %%
plt.figure(figsize=(10,4))
sns.boxplot(y=a[a['Retweets'] > 0]['Retweets'])
plt.title("Box plot for Retweets")
plt.ylabel("Number of Retweets")
plt.show()

# %% [markdown]
# #### Interpretation :
#     This Box Plot shows the distribution of Retweets.
#     The median values of Retweets is around 22.
#     The InterQuartile Range is about 17 to 25 retweets.
#     The minimum retweet is about 7 and maximum retweet is about 35.

# %% [markdown]
# #### c) Scatter Plot

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=a['Likes'],y=a['Retweets'],hue=a['Platform'])
plt.title("Scatter Plot for Likes vs Retweets on Platforms")
plt.xlabel("Number of Likes")
plt.ylabel("Number of Retweets")
plt.show()

# %% [markdown]
# #### Interpretation :
#     This Scatter plot shows the relationship between Number of Likes and Number of Retweets on different platforms.
#     Here different colours represents different platforms :
#         Blue & Red -> Twitter, Yellow -> Instagram, Green -> Facebook.
#     This graph clearly indicates that there are more number of likes and retweets on Twitter than other platforms.

# %% [markdown]
# ### 7. Correlation

# %%
print(a.corr(numeric_only=True))
# Out:
#               Unnamed: 0.1  Unnamed: 0  Retweets     Likes      Year  \
# Unnamed: 0.1      1.000000    0.999995  0.388637  0.376208  0.101578
# Unnamed: 0        0.999995    1.000000  0.388884  0.376472  0.100749
# Retweets          0.388637    0.388884  1.000000  0.998482 -0.039982
# Likes             0.376208    0.376472  0.998482  1.000000 -0.043415
# Year              0.101578    0.100749 -0.039982 -0.043415  1.000000
# Month             0.443013    0.443523  0.073265  0.066643 -0.314845
# Day              -0.080101   -0.080480  0.009213  0.011489  0.021973
# Hour              0.322371    0.322163  0.196955  0.195331 -0.087470
#
#                  Month       Day      Hour
# Unnamed: 0.1  0.443013 -0.080101  0.322371
# Unnamed: 0    0.443523 -0.080480  0.322163
# Retweets      0.073265  0.009213  0.196955
# Likes         0.066643  0.011489  0.195331
# Year         -0.314845  0.021973 -0.087470
# Month         1.000000 -0.135873  0.137835
# ...

# %%
cm = a.corr(numeric_only=True)
plt.figure(figsize=(12,6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='.2f')
plt.title("Correlation of numerical features")
plt.show()

# %% [markdown]
# #### Interpretation :
#     The heatmap shows the correlation between numerical features.
#     Darker shades = Highly Correlated, Lighter Shades = Lightly Correlated.
#     As we can se Likes & Retweets are highly correlated which means if one increases the other one also increases.
